# %%
import sys, os, glob
import numpy as np
import glob
import matplotlib.pyplot as plt
sys.path.append(os.getenv('src_dir'))
from src.pre_process_grd._load_image import s1_load

# %%
image_paths = glob.glob(f'{os.getenv("raw_data_dir")}/*/*/*.SAFE')

# %%
img = s1_load(image_paths[0])
img.simple_plot(band_index=0,stride=50)

# %% [markdown]
# Gamma calibration

# %%
img_cal = img.calibrate(mode='gamma',tiles=3)

# %%
img_cal.unit
# Out:
# 'gamma'

# %%
img_cal.simple_plot(band_index=0,stride=50)
