# %%
import sys, os, glob
import numpy as np
import glob
import matplotlib.pyplot as plt
sys.path.append(os.getenv('src_dir'))
from src.pre_process_grd._load_image import s1_load

# %%
image_paths = glob.glob(f'{os.getenv("raw_data_dir")}/*/*/*.SAFE')

# %%
img = s1_load(image_paths[0])
img =img.calibrate(mode='sigma_0')
img.simple_plot(band_index=0,stride=50)

# %%
img_box = img.boxcar(11)
img_box.simple_plot(band_index=0,q_max=0.99)

# %%
img_box = img_box.to_db()
img_box.simple_plot(0,0.99)
# Out:
# /Users/kaaso/Documents/phd/coding/Sentinel_1_python/examples/../src/pre_process_grd/Process.py:230: RuntimeWarning: divide by zero encountered in log
#   db_bands.append(10 * np.log(band))
