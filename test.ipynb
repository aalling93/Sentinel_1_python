# %%
import sentinel_download
from sentinel_download import Sentinel_metadata, Satellite_download

# %%
with Sentinel_metadata() as met:
    met.area([5,10,55,60])
    met.get_metadata(sensor='s1_grd',start_data='20191209',end_date='20191212')
    met.iw()
    met.land()
    met.plot_image_areas()
    met.show_cross_pol(5)
# Out:
# /Users/kaaso/Documents/phd/coding/modules/sentinel_data/sentinel_download/_utilities.py:35: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   lon = df.geometry.to_crs(4326).centroid.x.values
# /Users/kaaso/Documents/phd/coding/modules/sentinel_data/sentinel_download/_utilities.py:36: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   lat = df.geometry.to_crs(4326).centroid.y.values

# %%
with Satellite_download(met.products_df[0:3]) as dwl:
    dwl.download_thumbnails(folder='delete_me')
